# %% [markdown]
# pep

# %%
def greet ():
     print ("Hello world!")

# %% [markdown]
# NAMING conventions in PTYHON

# %%
student_name="Peter"# snake casing for var and func
total_marks= 95



def calculate_average():
    total_marks= 95


#constants should be in CAPS
MAX_MAXIMUM = 95
PI = 3.14


#Classes: PASCAL CASE

class StudentRecord:
    pass

# %% [markdown]
# LINE LENGTH IN PY

# %%
first_semester = 56
second_semester = 67
third_semester = 78
activity_marks = 89


semester_marks = (first_semester + second_semester + third_semester + activity_marks) #wrong format


semester =(first_semester 
         + second_semester
          + third_semester
          + activity_marks) #correct format

# %%
print(semester_marks)
print(semester)
# Out:
# 290
# 290

# %% [markdown]
# SPACES AROUND OPERATORS

# %%
y = 7 + 9
z = 9 + 8


q=9+6 # this is wrong format

# %%
print(y + z + q) # correct format
# Out:
# 48

# %%
pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.1
# colorama                0.4.6
# comm                    0.2.3
# debugpy                 1.8.21
# decorator               5.3.1
# executing               2.2.1
# ipykernel               7.3.0
# ipython                 9.15.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.20.0
# jupyter_client          8.9.1
# jupyter_core            5.9.1
# matplotlib-inline       0.2.2
# nest-asyncio2           1.7.2
# packaging               26.2
# parso                   0.8.7
# pip                     26.1.2
# platformdirs            4.10.0
# prompt_toolkit          3.0.52
# psutil                  7.2.2
# pure_eval               0.2.3
# Pygments                2.20.0
# python-dateutil         2.9.0.post0
# pyzmq                   27.1.0
# six                     1.17.0
# stack-data              0.6.3
# tornado                 6.5.7
# traitlets               5.15.1
# ...

# %%
# %pip install pandas numpy matplotlib seaborn sklearn scikit-learn
# Out:
# ...
#   Using cached pandas-3.0.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.5.0-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached matplotlib-3.11.0-cp314-cp314-win_amd64.whl.metadata (80 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.1
# colorama                0.4.6
# comm                    0.2.3
# contourpy               1.3.3
# cycler                  0.12.1
# debugpy                 1.8.21
# decorator               5.3.1
# executing               2.2.1
# fonttools               4.63.0
# ipykernel               7.3.0
# ipython                 9.15.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.20.0
# joblib                  1.5.3
# jupyter_client          8.9.1
# jupyter_core            5.9.1
# kiwisolver              1.5.0
# matplotlib              3.11.0
# matplotlib-inline       0.2.2
# narwhals                2.22.1
# nest-asyncio2           1.7.2
# numpy                   2.5.0
# packaging               26.2
# pandas                  3.0.3
# parso                   0.8.7
# pillow                  12.2.0
# pip                     26.1.2
# platformdirs            4.10.0
# ...
